# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#Define image size  and batch size
IMG_SIZE=224
BATCH_Size=32

# %%
#define data generators for train,validation and test sets
train_datagen = ImageDataGenerator(rescale=1./225,validation_split=0.2)
train_generator = train_datagen.flow_from_directory(''
target_size=(IMG_SIZE,IMG_SIZE),
bastch_size=BATCH_SIZE,
class_mode='binary'
subset='training')

# %%
val_generator = train_datagen.flow_from_directory(''
target_size=(IMG_SIZE,IMG_SIZE),
bastch_size=BATCH_SIZE,
class_mode='binary'
subset='validation')

# %%
train_datagen = ImageDataGenerator(rescale=1./225)
train_generator = train_datagen.flow_from_directory(''
target_size=(IMG_SIZE,IMG_SIZE),
bastch_size=BATCH_SIZE,
class_mode='binary'
)

# %%
from google.cloab import drive
drive.mount('')

# %%
#define the model
model=keras.sequential([layer.con2D(32,(3,3),activation='relu',input_shape=(IMG_SIZE,IMG_SIZE)
layer.MaxPooling2D((2,2)),
)])
